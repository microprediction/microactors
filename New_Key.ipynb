# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/microactors/blob/main/New_Key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install microprediction

# %%
from microprediction import new_key
write_key = new_key(difficulty=10)
print(write_key)
